# %%
import pandas as pd
Data = pd.DataFrame({ 'name':['amit','rajesh','suresh'],
                   'emp_data':[121,131,141]    
})

# %%
Data[0:2]
# Out:
#      name  emp_data
# 0    amit       121
# 1  rajesh       131

# %%
omdb = pd.read_csv("C:\Users\600034724\Desktop\Data Science\omdb.csv")
# Out:
#   File "<ipython-input-9-c2844487cf9b>", line 1
#     omdb = pd.read_csv("C:\Users\600034724\Desktop\Data Science\omdb.csv")
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# # it gave error coz it doesnt recognize backslash so we have to give fwd slash

# %%
omdb = pd.read_csv("C:/Users/600034724/Desktop/Data Science/omdb.csv")

# %%
omdb
# Out:
#             ID     imdbID                                             Title  \
# 0         4972  tt0004972                             The Birth of a Nation
# 1         6206  tt0006206                                      Les vampires
# 2         6864  tt0006864  Intolerance: Love's Struggle Throughout the Ages
# 3         9470  tt0009470                                      Over the Top
# 4         9968  tt0009968    Broken Blossoms or The Yellow Man and the Girl
# 5        10323  tt0010323                       The Cabinet of Dr. Caligari
# 6        11130  tt0011130                           Dr. Jekyll and Mr. Hyde
# 7        11841  tt0011841                                     Way Down East
# 8        12349  tt0012349                                           The Kid
# 9        12532  tt0012532                              Orphans of the Storm
# 10       12920  tt0012920                                         Barb Wire
# ...

# %%
omdb.head()
# Out:
#      ID     imdbID                                             Title  Year  \
# 0  4972  tt0004972                             The Birth of a Nation  1915
# 1  6206  tt0006206                                      Les vampires  1915
# 2  6864  tt0006864  Intolerance: Love's Struggle Throughout the Ages  1916
# 3  9470  tt0009470                                      Over the Top  1918
# 4  9968  tt0009968    Broken Blossoms or The Yellow Man and the Girl  1919
#
#       Rating  Runtime                     Genre    Released         Director  \
# 0  Not Rated      165   Drama, History, Romance  1915-03-03    D.W. Griffith
# 1  Not Rated      399  Action, Adventure, Crime  1915-11-13  Louis Feuillade
# 2  Not Rated      197            Drama, History  1916-09-05    D.W. Griffith
# 3        NaN        0                Drama, War  1918-03-31    Wilfrid North
# 4  Not Rated       90            Drama, Romance  1919-10-20    D.W. Griffith
#
# ...

# %%
omdb.tail()
# Out:
#             ID     imdbID                              Title  Year Rating  \
# 12564  3210686  tt3210686                         Son of God  2014  PG-13
# 12565  3228928  tt3228928  The Prime Ministers: The Pioneers  2013    NaN
# 12566  3234082  tt3234082                           12-12-12  2013      R
# 12567  3263614  tt3263614        Kumiko, the Treasure Hunter  2014    NaN
# 12568  3404140  tt3404140                       The Attorney  2013    NaN
#
#        Runtime        Genre    Released             Director  \
# 12564      138        Drama  2014-02-28  Christopher Spencer
# 12565        0  Documentary  2013-10-18        Richard Trank
# 12566      105  Documentary  2013-11-01         Amir Bar-Lev
# 12567      105        Drama  2014-01-20        David Zellner
# 12568      127        Drama  2014-02-07        Woo-seok Yang
#
#                                                   Writer  \
# 12564  Richard Bedser, Christopher Spencer, Colin Swa...
# ...

# %%
tomatoes = pd.read_csv("C:/Users/600034724/Desktop/Data Science/tomatoes.csv")

# %%
tomatoes.head()
# Out:
#    ID Image  Rating  Meter  Reviews  Fresh  Rotten Consensus  userMeter  \
# 0   4   NaN     NaN   17.0      NaN    NaN     NaN       NaN       17.0
# 1   5   NaN     NaN   39.0      NaN    NaN     NaN       NaN       39.0
# 2  10   NaN     NaN   20.0      NaN    NaN     NaN       NaN       20.0
# 3  75   NaN     NaN    NaN      NaN    NaN     NaN       NaN        NaN
# 4  89   NaN     NaN    0.0      NaN    NaN     NaN       NaN        0.0
#
#    userRating  userReviews  DVD  BoxOffice Production Website  \
# 0         2.8        215.0  NaN        NaN        NaN     NaN
# 1         3.1        169.0  NaN        NaN        NaN     NaN
# 2         NaN        109.0  NaN        NaN        NaN     NaN
# 3         NaN          4.0  NaN        NaN        NaN     NaN
# 4         NaN         50.0  NaN        NaN        NaN     NaN
#
#            lastUpdated
# 0  2012-10-01 00:00:00
# 1  2012-10-01 00:00:00
# 2  2012-10-04 00:00:00
# 3  2012-09-27 00:00:00
# 4  2012-10-01 00:00:00

# %%
omdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12569 entries, 0 to 12568
# Data columns (total 19 columns):
# ID             12569 non-null int64
# imdbID         12569 non-null object
# Title          12569 non-null object
# Year           12569 non-null int64
# Rating         10353 non-null object
# Runtime        12569 non-null int64
# Genre          12548 non-null object
# Released       12381 non-null object
# Director       12549 non-null object
# Writer         11852 non-null object
# Cast           12412 non-null object
# Metacritic     7649 non-null float64
# imdbRating     12549 non-null float64
# imdbVotes      12548 non-null float64
# Language       12340 non-null object
# Country        12392 non-null object
# Awards         9581 non-null object
# lastUpdated    12569 non-null object
# Oscars         12569 non-null int64
# dtypes: float64(3), int64(4), object(12)
# memory usage: 1.8+ MB

# %%
tomatoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76430 entries, 0 to 76429
# Data columns (total 16 columns):
# ID             76430 non-null int64
# Image          17530 non-null object
# Rating         17530 non-null float64
# Meter          51284 non-null float64
# Reviews        32198 non-null float64
# Fresh          32198 non-null float64
# Rotten         32198 non-null float64
# Consensus      5617 non-null object
# userMeter      63559 non-null float64
# userRating     57047 non-null float64
# userReviews    68102 non-null float64
# DVD            24010 non-null object
# BoxOffice      4552 non-null float64
# Production     20769 non-null object
# Website        10000 non-null object
# lastUpdated    76430 non-null object
# dtypes: float64(9), int64(1), object(6)
# memory usage: 9.3+ MB

# %%
omdb.describe()
# Out:
#                  ID          Year       Runtime   Metacritic    imdbRating  \
# count  1.256900e+04  12569.000000  12569.000000  7649.000000  12549.000000
# mean   5.883665e+05   1996.328666    102.746360    56.880246      6.610232
# std    6.527809e+05     17.690950     23.529907    17.390980      1.010695
# min    4.972000e+03   1902.000000      0.000000     1.000000      1.100000
# 25%    1.038590e+05   1991.000000     91.000000    45.000000      6.000000
# 50%    3.002140e+05   2002.000000    100.000000    58.000000      6.700000
# 75%    9.971670e+05   2008.000000    112.000000    70.000000      7.300000
# max    3.404140e+06   2014.000000    566.000000   100.000000      9.300000
#
#           imdbVotes        Oscars
# count  1.254800e+04  12569.000000
# mean   2.748591e+04      0.107089
# std    6.507364e+04      0.604977
# min    5.000000e+00      0.000000
# 25%    1.551750e+03      0.000000
# 50%    5.612000e+03      0.000000
# 75%    2.269975e+04      0.000000
# ...

# %%
omdb.ind = omdb.set_index('ID',inplace=True)

# %%
omdb.head()
# Out:
#          imdbID                                             Title  Year  \
# ID
# 4972  tt0004972                             The Birth of a Nation  1915
# 6206  tt0006206                                      Les vampires  1915
# 6864  tt0006864  Intolerance: Love's Struggle Throughout the Ages  1916
# 9470  tt0009470                                      Over the Top  1918
# 9968  tt0009968    Broken Blossoms or The Yellow Man and the Girl  1919
#
#          Rating  Runtime                     Genre    Released  \
# ID
# 4972  Not Rated      165   Drama, History, Romance  1915-03-03
# 6206  Not Rated      399  Action, Adventure, Crime  1915-11-13
# 6864  Not Rated      197            Drama, History  1916-09-05
# 9470        NaN        0                Drama, War  1918-03-31
# 9968  Not Rated       90            Drama, Romance  1919-10-20
#
#              Director                                             Writer  \
# ID
# ...

# %%
omdb.sort_values(by="Director").head()
# Out:
#             imdbID                           Title  Year Rating  Runtime  \
# ID
# 343172   tt0343172                What Alice Found  2003      R       96
# 304081   tt0304081  Gigantic (A Tale of Two Johns)  2002    NaN      102
# 1292645  tt1292645                      Convention  2009    NaN       95
# 790769   tt0790769         Kurt Cobain About a Son  2006    NaN       96
# 1014809  tt1014809        Until the Light Takes Us  2008    NaN       93
#
#                       Genre    Released                   Director  \
# ID
# 343172         Crime, Drama  2003-01-26               A. Dean Bell
# 304081   Documentary, Music  2002-03-10                 AJ Schnack
# 1292645         Documentary  2009-06-01                 AJ Schnack
# 790769   Documentary, Music  2007-10-03                 AJ Schnack
# 1014809  Documentary, Music  2010-08-12  Aaron Aites, Audrey Ewell
#
#                Writer                                               Cast  \
# ID
# ...

# %%
Data
# Out:
#      name  emp_data
# 0    amit       121
# 1  rajesh       131
# 2  suresh       141

# %%
Data['emp_data']
# Out:
# 0    121
# 1    131
# 2    141
# Name: emp_data, dtype: int64
